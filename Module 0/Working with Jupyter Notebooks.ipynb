# %% [markdown]
# # This is a markdown cell

# %%
print('Hello World!')
# Out:
# Hello World!

# %%
print('hello')
# Out:
# hello

# %%
print('hello)
# Out:
#   Cell In[3], line 1
#     print('hello)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)
